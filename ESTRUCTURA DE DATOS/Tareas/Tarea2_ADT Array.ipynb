# %%
"""
Implementar los siguientes métodos ADT Array
setItem ( dato , index ) --> establecer un elemento en la posición establecida
getLenght()  🡪 Obtener el tamaño del arreglo.
clear( dato) 🡪 establece todos los valores del ADT al valor enviado en dato.

"""

# %%
#setItem ( dato , index )
class point(object):
    def __init__(self,x=0,y=0):
        self.x=x
        self.y=y

    def __str__(self):
        return "point(%s,%s)"%(self.x,self.y)

    def __getitem__(self,item):
        return (self.x, self.y)[item]

    def __setitem__(self,x,y):
        [self.x, self.y][x]=y

# %%
# getLenght()

Lista = [7,15,33,40]
get_length = len(Lista)
print("Tamaño de la lista:",get_length)
# Out:
# Tamaño de la lista: 4

# %%
#clear( dato)
Lista = [7,15,33,40]
print("Lista:",Lista)
Lista.clear()
print("Lista:",Lista)
# Out:
# Lista: [7, 15, 33, 40]
# Lista: []
